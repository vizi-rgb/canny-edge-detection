# %%
from experiment import Experiment

exp = Experiment("./data/ronaldo.jpg", 100.5, 220.4, True)
edges = exp.run()

# %%
from experiment import ExperimentPlotter

exp2 = Experiment("./data/PKiN_widziany_z_WFC.jpg", 100.5, 220.4, True)
plotter = ExperimentPlotter()
plotter.plot_edges(exp)
plotter.plot_edges([exp, exp2, exp2, exp])

# %%
import cv2 as cv  # pyright: ignore[reportMissingImports]
exp_blur = Experiment("./data/ronaldo.jpg", 100.5, 220.4, True, preprocessing_function=lambda img: cv.GaussianBlur(img, (5, 5), 0))
exp_no_blur = Experiment("./data/ronaldo.jpg", 100.5, 220.4, True)
ExperimentPlotter.plot_edges([exp_blur, exp_no_blur])
